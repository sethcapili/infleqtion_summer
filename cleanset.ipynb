# %% [markdown]
# ## Clean JSON for 5 Prompting Strategies
#
# Strategies:
#
# Strategy 1: direct prompt
# Strategy 2: stricter prompt
# Strategy 3: few-shot prompt
# Strategy 4: structured JSON prompt
# Strategy 5: structured JSON + validator repair loop
# Strategy 6: fine-tuned model, only if clean data is ready

# %% [markdown]
# ### JSON Schema
#
# Formal schema for one circuit record, used to validate every entry added to
# `dataset` via `add_record()`. Matches the real output of `validate_circuit()`
# in `repair_validator.ipynb`.

# %%
Dataset = [
    {
        'circuit_type': 'Bell State',
        'prompting_strategy': '1',
        'prompt': '"Prepare the Bell state |Phi+> on two qubits."',
        'checks': {
            'syntax': False,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False,
        },
        'error_categories': ['invalid_syntax'],
        'score': 0,
        'fully_correct': False,
        'verdict': 'invalid_syntax',
        'reason': 'invalid syntax (<string>, line 3)',
    },
    {
        'circuit_type': 'Bell State',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Prepare the Bell state |Phi+> on two qubits."""',
       'checks': {
           'syntax': True,
           'execution': True,
           'qubits': True,
           'gates': True,
           'measurement': True,
           'statevector': True,
           'simulation': True,
        },
        'error_categories': [],
        'score': 100,
        'fully_correct': True,
        'verdict': 'success',
        'reason': '',
    },
    {
        'circuit_type': 'Bell State',
        'prompting_strategy': '3',
        'prompt': '"""Prepare the Bell state |Phi+> on two qubits. Only return parsed cirq python code. Use these expamples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': True,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False
            },
        'error_categories': ['execution_error'],
        'score': 14,
        'fully_correct': False,
        'verdict': 'execution_error',
        'reason': 'cannot unpack non-iterable LineQubit object',
    },
    {
        'circuit_type': 'Bell State',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare the Bell state |Phi+> on two qubits."""',
        'checks': {
            'syntax': True,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False
            },
        'error_categories': ['execution_error'],
        'score': 14,
        'fully_correct': False,
        'verdict': 'execution_error',
        'reason': "name 'false' is not defined",
    }, 
    {
        'circuit_type': 'Bell State',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare the Bell state |Phi+> on two qubits."""',
        'output': {
            "description": "Prepares the Bell state |Φ+> on two qubits using a Hadamard gate followed by a CNOT gate",
            "framework": "cirq",
            "num_qubits": 2,
            "code": "import cirq\nq0, q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit()\ncircuit.append([\n    cirq.H(q0),\n    cirq.CNOT(q0, q1)\n])\nprint(circuit)",
            "expected_gates": ["H", "CNOT"],
            "measurement_included": 'false',
            "expected_behavior": "The two qubits are entangled in the |Φ+> state, where measuring both qubits will yield correlated results of |00> or |11>",
        },
        'error_categories': [],
        'score': 100,
        'fully_correct': True,
        'verdict': 'fully_correct',
        'reason': 'The code was fully correct and produced the expected output.',
    },
    {
        'circuit_type': 'Bell State w/ Measurement',
        'prompting_strategy': '1',
        'prompt': '"Prepare the Bell state |Phi+> on two qubits. Measure the output. Result a Cirq ciruit."',
        'checks': {
            'syntax': False,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False,
        },
        'error_categories': ['invalid_syntax'],
        'score': 0,
        'fully_correct': False,
        'verdict': 'invalid_syntax',
        'reason': 'invalid syntax (<string>, line 3)',
    },
    {
        'circuit_type': 'Bell State w/ Measurement',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Prepare the Bell state |Phi+> on two qubits. Measure the output."""',
        'checks': {
            'syntax': True,
            'execution': True,
            'qubits': True,
            'gates': True,
            'measurement': True,
            'statevector': True,
            'simulation': True,
            },
        'error_categories': [],
        'score': 100,
        'fully_correct': True,
        'verdict': 'success',
        'reason': ''
    },
    {
        'circuit_type': 'Bell State w/ Measurement',
        'prompting_strategy': '3',
        'prompt': '"""You generate minimal valid Python code using Cirq. Examples: Prepare Hadamard - import cirq\nqubit = cirq.LineQubit(0)\nciruit = cirq.Circuit(cirq.H(qubit))\nprint(circuit). Prepare CNOT and Measure output - import cirq\nq0,q1 = cirq.LineQubit.range(2)\n circuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit) Request: Prepare the Bell state |Phi+> on two qubits. Measure the output."""',
        'checks': {
            'syntax': False,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False,
            },
        'error_categories': ['invalid_syntax'],
        'score': 0,
        'fully_correct': False,
        'verdict': 'invalid_syntax',
        'reason': 'invalid syntax (<string>, line 3)'
    },
    {
        'circuit_type': 'Bell State w/ Measurement',
        'prompting_strategy': '4',
        'prompt': '"""You generate minimal valid Python code using Cirq. Examples: Prepare Hadamard - import cirq\nqubit = cirq.LineQubit(0)\nciruit = cirq.Circuit(cirq.H(qubit))\nprint(circuit). Prepare CNOT and Measure output - import cirq\nq0,q1 = cirq.LineQubit.range(2)\n circuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit) Request: Prepare the Bell state |Phi+> on two qubits. Measure the output."""',
        'checks': {
            'syntax': False,
            'execution': False,
            'qubits': False,
            'gates': False,
            'measurement': False,
            'statevector': False,
            'simulation': False,
            },
        'error_categories': ['invalid_syntax'],
        'score': 0,
        'fully_correct': False,
        'verdict': 'invalid_syntax',
        'reason': 'invalid syntax (<string>, line 3)'
    },

    {
        'circuit_type': 'Bell State w/ Measurement',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare the Bell state |Phi+> on two qubits. Measure the output."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Two-Layer Variational Circuit',
        'prompting_strategy': '1',
        'prompt': '"Prepare a two-layer variational circuit on three qubits using RY gates followed by a CNOT ladder, repeated twice."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Two-Layer Variational Circuit',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Prepare a two-layer variational circuit on three qubits using RY gates followed by a CNOT ladder, repeated twice."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Two-Layer Variational Circuit',
        'prompting_strategy': '3',
        'prompt': '"""Prepare a two-layer variational circuit on three qubits using RY gates followed by a CNOT ladder, repeated twice. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Two-Layer Variational Circuit',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a two-layer variational circuit on three qubits using RY gates followed by a CNOT ladder, repeated twice."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Two-Layer Variational Circuit',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a two-layer variational circuit on three qubits using RY gates followed by a CNOT ladder, repeated twice."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Phase Kickback',
        'prompting_strategy': '1',
        'prompt': '"Demonstrate phase kickback using a control qubit in |+> and a target qubit in |1>, with a CNOT between them and a Hadamard on the control qubit."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Phase Kickback',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Demonstrate phase kickback using a control qubit in |+> and a target qubit in |1>, with a CNOT between them and a Hadamard on the control qubit."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Phase Kickback',
        'prompting_strategy': '3',
        'prompt': '"""Demonstrate phase kickback using a control qubit in |+> and a target qubit in |1>, with a CNOT between them and a Hadamard on the control qubit. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Phase Kickback',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Demonstrate phase kickback using a control qubit in |+> and a target qubit in |1>, with a CNOT between them and a Hadamard on the control qubit."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Phase Kickback',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Demonstrate phase kickback using a control qubit in |+> and a target qubit in |1>, with a CNOT between them and a Hadamard on the control qubit."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Hadamard (Single Qubit)',
        'prompting_strategy': '1',
        'prompt': '"Apply a Hadamard gate to a single qubit initialized in |0>."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Hadamard (Single Qubit)',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply a Hadamard gate to a single qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Hadamard (Single Qubit)',
        'prompting_strategy': '3',
        'prompt': '"""Apply a Hadamard gate to a single qubit initialized in |0>. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Hadamard (Single Qubit)',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Hadamard gate to a single qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Hadamard (Single Qubit)',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Hadamard gate to a single qubit initialized in |0>."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RZ Rotation',
        'prompting_strategy': '1',
        'prompt': '"Apply an RZ rotation gate with angle theta = pi/2 to a qubit initialized in the |+> state."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RZ Rotation',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply an RZ rotation gate with angle theta = pi/2 to a qubit initialized in the |+> state."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RZ Rotation',
        'prompting_strategy': '3',
        'prompt': '"""Apply an RZ rotation gate with angle theta = pi/2 to a qubit initialized in the |+> state. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RZ Rotation',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RZ rotation gate with angle theta = pi/2 to a qubit initialized in the |+> state."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RZ Rotation',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RZ rotation gate with angle theta = pi/2 to a qubit initialized in the |+> state."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'CNOT Gate',
        'prompting_strategy': '1',
        'prompt': '"Construct a two-qubit circuit with a CNOT gate, control qubit 0 initialized in |1>, target qubit 1."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'CNOT Gate',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Construct a two-qubit circuit with a CNOT gate, control qubit 0 initialized in |1>, target qubit 1."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'CNOT Gate',
        'prompting_strategy': '3',
        'prompt': '"""Construct a two-qubit circuit with a CNOT gate, control qubit 0 initialized in |1>, target qubit 1. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'CNOT Gate',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a two-qubit circuit with a CNOT gate, control qubit 0 initialized in |1>, target qubit 1."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'CNOT Gate',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a two-qubit circuit with a CNOT gate, control qubit 0 initialized in |1>, target qubit 1."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': "Grover's Diffusion Operator",
        'prompting_strategy': '1',
        'prompt': '"Implement Grover\'s diffusion operator on two qubits using Hadamard, Pauli-X, a multi-controlled Z, Pauli-X, and Hadamard gates."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': "Grover's Diffusion Operator",
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Implement Grover\'s diffusion operator on two qubits using Hadamard, Pauli-X, a multi-controlled Z, Pauli-X, and Hadamard gates."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': "Grover's Diffusion Operator",
        'prompting_strategy': '3',
        'prompt': '"""Implement Grover\'s diffusion operator on two qubits using Hadamard, Pauli-X, a multi-controlled Z, Pauli-X, and Hadamard gates. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': "Grover's Diffusion Operator",
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement Grover\'s diffusion operator on two qubits using Hadamard, Pauli-X, a multi-controlled Z, Pauli-X, and Hadamard gates."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': "Grover's Diffusion Operator",
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement Grover\'s diffusion operator on two qubits using Hadamard, Pauli-X, a multi-controlled Z, Pauli-X, and Hadamard gates."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Ambiguous Entanglement Prompt',
        'prompting_strategy': '1',
        'prompt': '"Make two qubits the same somehow."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Ambiguous Entanglement Prompt',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Make two qubits the same somehow."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Ambiguous Entanglement Prompt',
        'prompting_strategy': '3',
        'prompt': '"""Make two qubits the same somehow. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Ambiguous Entanglement Prompt',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Make two qubits the same somehow."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Ambiguous Entanglement Prompt',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Make two qubits the same somehow."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Teleportation',
        'prompting_strategy': '1',
        'prompt': '"Implement the quantum teleportation protocol using three qubits: a message qubit, and two entangled qubits as the quantum channel, with Bell measurement and classically controlled Pauli corrections."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Teleportation',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Implement the quantum teleportation protocol using three qubits: a message qubit, and two entangled qubits as the quantum channel, with Bell measurement and classically controlled Pauli corrections."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Teleportation',
        'prompting_strategy': '3',
        'prompt': '"""Implement the quantum teleportation protocol using three qubits: a message qubit, and two entangled qubits as the quantum channel, with Bell measurement and classically controlled Pauli corrections. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Teleportation',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement the quantum teleportation protocol using three qubits: a message qubit, and two entangled qubits as the quantum channel, with Bell measurement and classically controlled Pauli corrections."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Teleportation',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement the quantum teleportation protocol using three qubits: a message qubit, and two entangled qubits as the quantum channel, with Bell measurement and classically controlled Pauli corrections."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Toffoli Gate (CCNOT)',
        'prompting_strategy': '1',
        'prompt': '"Construct a three-qubit Toffoli (CCNOT) gate with qubits 0 and 1 as controls initialized in |1>, and qubit 2 as target."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Toffoli Gate (CCNOT)',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Construct a three-qubit Toffoli (CCNOT) gate with qubits 0 and 1 as controls initialized in |1>, and qubit 2 as target."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Toffoli Gate (CCNOT)',
        'prompting_strategy': '3',
        'prompt': '"""Construct a three-qubit Toffoli (CCNOT) gate with qubits 0 and 1 as controls initialized in |1>, and qubit 2 as target. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Toffoli Gate (CCNOT)',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a three-qubit Toffoli (CCNOT) gate with qubits 0 and 1 as controls initialized in |1>, and qubit 2 as target."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Toffoli Gate (CCNOT)',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a three-qubit Toffoli (CCNOT) gate with qubits 0 and 1 as controls initialized in |1>, and qubit 2 as target."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-Z Gate',
        'prompting_strategy': '1',
        'prompt': '"Apply a Pauli-Z gate to a single qubit initialized in the |+> state."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-Z Gate',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply a Pauli-Z gate to a single qubit initialized in the |+> state."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-Z Gate',
        'prompting_strategy': '3',
        'prompt': '"""Apply a Pauli-Z gate to a single qubit initialized in the |+> state. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-Z Gate',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Pauli-Z gate to a single qubit initialized in the |+> state."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-Z Gate',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Pauli-Z gate to a single qubit initialized in the |+> state."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RY Rotation',
        'prompting_strategy': '1',
        'prompt': '"Apply an RY rotation gate with angle theta = pi/2 to a qubit initialized in |0>."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RY Rotation',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply an RY rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RY Rotation',
        'prompting_strategy': '3',
        'prompt': '"""Apply an RY rotation gate with angle theta = pi/2 to a qubit initialized in |0>. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RY Rotation',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RY rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RY Rotation',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RY rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State (3-qubit)',
        'prompting_strategy': '1',
        'prompt': '"Prepare a three-qubit GHZ state using a Hadamard on qubit 0 and CNOT gates from qubit 0 to qubits 1 and 2."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State (3-qubit)',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Prepare a three-qubit GHZ state using a Hadamard on qubit 0 and CNOT gates from qubit 0 to qubits 1 and 2."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State (3-qubit)',
        'prompting_strategy': '3',
        'prompt': '"""Prepare a three-qubit GHZ state using a Hadamard on qubit 0 and CNOT gates from qubit 0 to qubits 1 and 2. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State (3-qubit)',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a three-qubit GHZ state using a Hadamard on qubit 0 and CNOT gates from qubit 0 to qubits 1 and 2."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State (3-qubit)',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a three-qubit GHZ state using a Hadamard on qubit 0 and CNOT gates from qubit 0 to qubits 1 and 2."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State w/ Measurement',
        'prompting_strategy': '1',
        'prompt': '"Prepare a three-qubit GHZ state and measure all three qubits."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State w/ Measurement',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Prepare a three-qubit GHZ state and measure all three qubits."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State w/ Measurement',
        'prompting_strategy': '3',
        'prompt': '"""Prepare a three-qubit GHZ state and measure all three qubits. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State w/ Measurement',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a three-qubit GHZ state and measure all three qubits."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'GHZ State w/ Measurement',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Prepare a three-qubit GHZ state and measure all three qubits."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'SWAP Gate',
        'prompting_strategy': '1',
        'prompt': '"Construct a two-qubit circuit with a SWAP gate, qubit 0 initialized in |1> and qubit 1 in |0>."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'SWAP Gate',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Construct a two-qubit circuit with a SWAP gate, qubit 0 initialized in |1> and qubit 1 in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'SWAP Gate',
        'prompting_strategy': '3',
        'prompt': '"""Construct a two-qubit circuit with a SWAP gate, qubit 0 initialized in |1> and qubit 1 in |0>. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'SWAP Gate',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a two-qubit circuit with a SWAP gate, qubit 0 initialized in |1> and qubit 1 in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'SWAP Gate',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Construct a two-qubit circuit with a SWAP gate, qubit 0 initialized in |1> and qubit 1 in |0>."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Single-Qubit Measurement',
        'prompting_strategy': '1',
        'prompt': '"Apply a Hadamard gate to a qubit initialized in |0> and measure it."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Single-Qubit Measurement',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply a Hadamard gate to a qubit initialized in |0> and measure it."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Single-Qubit Measurement',
        'prompting_strategy': '3',
        'prompt': '"""Apply a Hadamard gate to a qubit initialized in |0> and measure it. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Single-Qubit Measurement',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Hadamard gate to a qubit initialized in |0> and measure it."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Single-Qubit Measurement',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Hadamard gate to a qubit initialized in |0> and measure it."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RX Rotation',
        'prompting_strategy': '1',
        'prompt': '"Apply an RX rotation gate with angle theta = pi/2 to a qubit initialized in |0>."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RX Rotation',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply an RX rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RX Rotation',
        'prompting_strategy': '3',
        'prompt': '"""Apply an RX rotation gate with angle theta = pi/2 to a qubit initialized in |0>. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RX Rotation',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RX rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'RX Rotation',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply an RX rotation gate with angle theta = pi/2 to a qubit initialized in |0>."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-X Gate',
        'prompting_strategy': '1',
        'prompt': '"Apply a Pauli-X gate to a single qubit initialized in |0>."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-X Gate',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Apply a Pauli-X gate to a single qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-X Gate',
        'prompting_strategy': '3',
        'prompt': '"""Apply a Pauli-X gate to a single qubit initialized in |0>. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-X Gate',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Pauli-X gate to a single qubit initialized in |0>."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Pauli-X Gate',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Apply a Pauli-X gate to a single qubit initialized in |0>."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Fourier Transform (3-qubit)',
        'prompting_strategy': '1',
        'prompt': '"Implement the 3-qubit Quantum Fourier Transform using Hadamard gates, controlled phase rotation gates, and a final SWAP-based qubit reversal."',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Fourier Transform (3-qubit)',
        'prompting_strategy': '2',
        'prompt': '"""You generate minimal valid Python code using Cirq. Rules: - Return only Python code. - Do not use Markdown code fences. - Import cirq. - Define a variable named circuit. - Use cirq.LineQubit.range(n) when possible. - Do not simulate the circuit unless the user explicitly asks for simulation. - Do not add measurements unless the user explicitly asks for measurements. - Print only the circuit. Request: Implement the 3-qubit Quantum Fourier Transform using Hadamard gates, controlled phase rotation gates, and a final SWAP-based qubit reversal."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Fourier Transform (3-qubit)',
        'prompting_strategy': '3',
        'prompt': '"""Implement the 3-qubit Quantum Fourier Transform using Hadamard gates, controlled phase rotation gates, and a final SWAP-based qubit reversal. Only return parsed cirq python code. Use these examples as a guide: import cirq\nqubit = cirq.LineQubit(0)\ncircuit = cirq.Circuit(cirq.H(qubit))\nprint(circuit) and import cirq\nq0,q1 = cirq.LineQubit.range(2)\ncircuit = cirq.Circuit(cirq.CNOT(q0,q1))\nprint(circuit)"""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Fourier Transform (3-qubit)',
        'prompting_strategy': '4',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement the 3-qubit Quantum Fourier Transform using Hadamard gates, controlled phase rotation gates, and a final SWAP-based qubit reversal."""',
        'checks': {
            'syntax': None,
            'execution': None,
            'qubits': None,
            'gates': None,
            'measurement': None,
            'statevector': None,
            'simulation': None,
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
    {
        'circuit_type': 'Quantum Fourier Transform (3-qubit)',
        'prompting_strategy': '5',
        'prompt': '"""Return valid JSON only. Do not include Markdown. The JSON schema must be: {"description": string, "framework": "cirq", "num_qubits": integer, "code": string, "expected_gates": list[string], "measurement_included": boolean, "expected_behavior": string} User request: Implement the 3-qubit Quantum Fourier Transform using Hadamard gates, controlled phase rotation gates, and a final SWAP-based qubit reversal."""',
        'output': {
            "description": "",
            "framework": "cirq",
            "num_qubits": None,
            "code": "",
            "expected_gates": [],
            "measurement_included": None,
            "expected_behavior": "",
        },
        'error_categories': [],
        'score': None,
        'fully_correct': None,
        'verdict': 'pending',
        'reason': '',
    },
]
